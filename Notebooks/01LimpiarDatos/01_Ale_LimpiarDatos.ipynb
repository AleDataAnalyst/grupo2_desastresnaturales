# %% [markdown]
# # Exploración de datos

# %% [markdown]
# Usando dataset 02desastres_paralimpiar.csv

# %% [markdown]
# Objetivos:
# Cargar dataset, shape, info, describe, columns, nulls

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_csv('../../Data/02ParaLimpiar/02desastres_paralimpiar.csv', encoding='latin-1', delimiter=';', engine='python')
# encoding='utf8' da problemas
# dejar engine='python' para evitar advertencias

# %% [markdown]
# ### Muestras head, slice 500:520 y tail

# %%
df.head(5)
# Out:
#           Dis No  Year   Seq Glide Disaster Group Disaster Subgroup
# 0  1900-9002-CPV  1900  9002   NaN        Natural    Climatological  \
# 1  1900-9001-IND  1900  9001   NaN        Natural    Climatological
# 2  1902-0012-GTM  1902    12   NaN        Natural       Geophysical
# 3  1902-0003-GTM  1902     3   NaN        Natural       Geophysical
# 4  1902-0010-GTM  1902    10   NaN        Natural       Geophysical
#
#        Disaster Type Disaster Subtype Disaster Subsubtype   Event Name  ...
# 0            Drought          Drought                 NaN          NaN  ...  \
# 1            Drought          Drought                 NaN          NaN  ...
# 2         Earthquake  Ground movement                 NaN          NaN  ...
# 3  Volcanic activity         Ash fall                 NaN  Santa Maria  ...
# 4  Volcanic activity         Ash fall                 NaN  Santa Maria  ...
#
#   Reconstruction Costs Adj Insured Damages Insured Damages Adj Total Damages
# ...

# %%
df[500:520]
# Out:
#             Dis No  Year   Seq Glide Disaster Group Disaster Subgroup
# 500  1969-9006-BEN  1969  9006   NaN        Natural    Climatological  \
# 501  1969-9006-BFA  1969  9006   NaN        Natural    Climatological
# 502  1969-9006-CPV  1969  9006   NaN        Natural    Climatological
# 503  1969-9006-GMB  1969  9006   NaN        Natural    Climatological
# 504  1969-9006-GNB  1969  9006   NaN        Natural    Climatological
# 505  1969-0004-BFA  1969     4   NaN        Natural        Biological
# 506  1969-0099-BFA  1969    99   NaN        Natural        Biological
# 507  1969-0065-BGD  1969    65   NaN        Natural    Meteorological
# 508  1969-0048-BOL  1969    48   NaN        Natural        Biological
# 509  1969-0108-BOL  1969   108   NaN        Natural        Biological
# 510  1969-0057-BRA  1969    57   NaN        Natural      Hydrological
# 511  1969-0082-CHN  1969    82   NaN        Natural       Geophysical
# ...

# %%
df.tail(5)
# Out:
#               Dis No  Year  Seq           Glide Disaster Group
# 16631  2023-0110-ZMB  2023  110             NaN        Natural  \
# 16632  2023-0068-ZMB  2023   68  EP-2023-000013        Natural
# 16633  2023-0095-ZWE  2023   95             NaN        Natural
# 16634  2023-0022-SRB  2023   22             NaN        Natural
# 16635  2023-0140-SSD  2023  140  EP-2023-000039        Natural
#
#       Disaster Subgroup Disaster Type   Disaster Subtype Disaster Subsubtype
# 16631      Hydrological         Flood        Flash flood                 NaN  \
# 16632        Biological      Epidemic  Bacterial disease                 NaN
# 16633    Meteorological         Storm   Tropical cyclone                 NaN
# 16634      Hydrological         Flood     Riverine flood                 NaN
# 16635        Biological      Epidemic  Bacterial disease                 NaN
#
#                       Event Name  ... Reconstruction Costs Adj
# ...

# %% [markdown]
# ## shape, info, dtypes

# %%
df.shape
# Resultado: 16636 filas y 50 columnas)
# Out:
# (16636, 50)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16636 entries, 0 to 16635
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Dis No                    16636 non-null  object
#  1   Year                      16636 non-null  int64
#  2   Seq                       16636 non-null  int64
#  3   Glide                     1736 non-null   object
#  4   Disaster Group            16636 non-null  object
#  5   Disaster Subgroup         16636 non-null  object
#  6   Disaster Type             16636 non-null  object
#  7   Disaster Subtype          13313 non-null  object
#  8   Disaster Subsubtype       1117 non-null   object
#  9   Event Name                3969 non-null   object
#  10  Country                   16636 non-null  object
#  11  ISO                       16636 non-null  object
#  12  Region                    16636 non-null  object
# ...

# %%
df.dtypes
# Out:
# Dis No                       object
# Year                          int64
# Seq                           int64
# Glide                        object
# Disaster Group               object
# Disaster Subgroup            object
# Disaster Type                object
# Disaster Subtype             object
# Disaster Subsubtype          object
# Event Name                   object
# Country                      object
# ISO                          object
# Region                       object
# Continent                    object
# Location                     object
# Origin                       object
# Associated Dis               object
# Associated Dis2              object
# OFDA Response                object
# Appeal                       object
# Declaration                  object
# AID Contribution            float64
# Dis Mag Value               float64
# Dis Mag Scale                object
# Latitude                     object
# Longitude                    object
# ...

# %% [markdown]
# ## Columnas

# %%
df.columns
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'AID Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Reconstruction Costs', 'Reconstruction Costs Adj',
#        'Insured Damages', 'Insured Damages Adj', 'Total Damages',
#        'Total Damages Adj', 'CPI', 'Adm Level', 'Admin1 Code', 'Admin2 Code',
#        'Geo Locations'],
#       dtype='object')

# %% [markdown]
# ### Columnas con valores numéricos: 21
#
# Year                                           int64,
# Seq                                            int64,
# AID Contribution                             float64,
# Dis Mag Value                                float64,
# Year                                         int64,
# Start Month                                  float64,
# Start Day                                    float64,
# End Year                                       int64,
# End Month                                    float64,
# End Day                                      float64,
# Total Deaths                                 float64,
# No Injured                                   float64,
# No Affected                                  float64,
# No Homeless                                  float64,
# Total Affected                               float64,
# Reconstruction Costs                         float64,
# Reconstruction Costs, Adjusted               float64,
# Insured Damages                              float64,
# Insured Damages, Adjusted                    float64,
# Total Damages                                float64,
# Total Damages, Adjusted                      float64

# %% [markdown]
# ### Columnas con variables categóricas: 25
#
# Dis No, Glide, Disaster Group, Disaster Subgroup, Disaster Type, Disaster Subtype, Disaster Subsubtype, Event Name, Country, ISO, Region, Continent, Location, Origin, Associated Dis, Associated Dis2, OFDA Response, Appeal, Declaration, Dis Mag Scale, Latitude, Longitude, Local Time, River Basin

# %% [markdown]
# ## Estadísticas básicas (columnas originales)

# %% [markdown]
# .describe

# %%
df.describe(include='all')
# Out:
#                Dis No          Year           Seq           Glide
# count           16636  16636.000000  16636.000000            1736  \
# unique          16636           NaN           NaN            1200
# top     1900-9002-CPV           NaN           NaN  CW-2012-000006
# freq                1           NaN           NaN              29
# mean              NaN   1997.838363    724.950228             NaN
# std               NaN     20.353457   1940.995621             NaN
# min               NaN   1900.000000      1.000000             NaN
# 25%               NaN   1990.000000     95.000000             NaN
# 50%               NaN   2002.000000    274.000000             NaN
# 75%               NaN   2012.000000    495.000000             NaN
# max               NaN   2023.000000   9881.000000             NaN
#
#        Disaster Group Disaster Subgroup Disaster Type Disaster Subtype
# count           16636             16636         16636            13313  \
# ...

# %%
df.columns
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Glide', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'Disaster Subsubtype',
#        'Event Name', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'AID Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Reconstruction Costs', 'Reconstruction Costs Adj',
#        'Insured Damages', 'Insured Damages Adj', 'Total Damages',
#        'Total Damages Adj', 'CPI', 'Adm Level', 'Admin1 Code', 'Admin2 Code',
#        'Geo Locations'],
#       dtype='object')

# %% [markdown]
# ## Borrar columnas

# %%
df.drop(columns=['Event Name', 'Disaster Group', 'Disaster Subsubtype', 'Glide', 'Adm Level', 'Admin1 Code', 'Admin2 Code', 'Geo Locations'], inplace=True)

# %% [markdown]
# ## Estadísticas básicas posteriores a borrar columnas

# %%
df.columns
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Disaster Subgroup', 'Disaster Type',
#        'Disaster Subtype', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'AID Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Local Time', 'River Basin',
#        'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month',
#        'End Day', 'Total Deaths', 'No Injured', 'No Affected', 'No Homeless',
#        'Total Affected', 'Reconstruction Costs', 'Reconstruction Costs Adj',
#        'Insured Damages', 'Insured Damages Adj', 'Total Damages',
#        'Total Damages Adj', 'CPI'],
#       dtype='object')

# %%
df.shape
# Out:
# (16636, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16636 entries, 0 to 16635
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Dis No                    16636 non-null  object
#  1   Year                      16636 non-null  int64
#  2   Seq                       16636 non-null  int64
#  3   Disaster Subgroup         16636 non-null  object
#  4   Disaster Type             16636 non-null  object
#  5   Disaster Subtype          13313 non-null  object
#  6   Country                   16636 non-null  object
#  7   ISO                       16636 non-null  object
#  8   Region                    16636 non-null  object
#  9   Continent                 16636 non-null  object
#  10  Location                  14825 non-null  object
#  11  Origin                    4085 non-null   object
#  12  Associated Dis            3593 non-null   object
# ...

# %%
df.head(1)
# Out:
#           Dis No  Year   Seq Disaster Subgroup Disaster Type Disaster Subtype
# 0  1900-9002-CPV  1900  9002    Climatological       Drought          Drought  \
#
#       Country  ISO          Region Continent  ... No Affected No Homeless
# 0  Cabo Verde  CPV  Western Africa    Africa  ...         NaN         NaN  \
#
#   Total Affected Reconstruction Costs Reconstruction Costs Adj
# 0            NaN                  NaN                      NaN  \
#
#   Insured Damages Insured Damages Adj  Total Damages  Total Damages Adj
# 0             NaN                 NaN            NaN                NaN  \
#
#            CPI
# 0  2,849084409
#
# [1 rows x 42 columns]

# %% [markdown]
# ## Outliers de Year

# %%
df['Year'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Gran cantidad de outliers antes de 1960

# %%
df['Year'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Tendencia a la alza en recopilación de datos de desastres a partir de 1980, siendo el pico más alto en la década del 2000

# %% [markdown]
# ## Valores faltantes

# %%
df.isnull().sum()
# Out:
# Dis No                          0
# Year                            0
# Seq                             0
# Disaster Subgroup               0
# Disaster Type                   0
# Disaster Subtype             3323
# Country                         0
# ISO                             0
# Region                          0
# Continent                       0
# Location                     1811
# Origin                      12551
# Associated Dis              13043
# Associated Dis2             15873
# OFDA Response               14920
# Appeal                      14077
# Declaration                 13293
# AID Contribution            15860
# Dis Mag Value               11572
# Dis Mag Scale                1220
# Latitude                    13861
# Longitude                   13861
# Local Time                  15480
# River Basin                 15300
# Start Year                      0
# Start Month                   395
# Start Day                    3615
# ...

# %%
df.isnull()
# Out:
#        Dis No   Year    Seq  Disaster Subgroup  Disaster Type
# 0       False  False  False              False          False  \
# 1       False  False  False              False          False
# 2       False  False  False              False          False
# 3       False  False  False              False          False
# 4       False  False  False              False          False
# ...       ...    ...    ...                ...            ...
# 16631   False  False  False              False          False
# 16632   False  False  False              False          False
# 16633   False  False  False              False          False
# 16634   False  False  False              False          False
# 16635   False  False  False              False          False
#
#        Disaster Subtype  Country    ISO  Region  Continent  ...  No Affected
# 0                 False    False  False   False      False  ...         True  \
# ...

# %% [markdown]
# ### Columnas (numéricas y categóricas) con más valores faltantes

# %% [markdown]
# Numéricas con más nulls:
# AID Contribution            15860
# Dis Mag Value               11572
# No Injured                  12489
# No Homeless                 14166
# Reconstruction Costs        16598
# Reconstruction Costs Adj    16600
# Insured Damages             15527
# Insured Damages Adj         15527
# Total Damages               11252
# Total Damages Adj           11270

# %% [markdown]
# Categóricas con más nulls:
# Origin                      12551
# Associated Dis              13043
# Associated Dis2             15873
# OFDA Response               14920
# Appeal                      14077
# Declaration                 13293
# Latitude                    13861
# Longitude                   13861
# Local Time                  15480
# River Basin                 15300

# %% [markdown]
# # Visualizaciones

# %% [markdown]
# ## Exploración de outliers en columnas numéricas (arriba de 10000 faltantes)

# %%
num_cols_outliers = ['AID Contribution', 'Dis Mag Value', 'No Injured', 'No Homeless', 'Reconstruction Costs', 'Reconstruction Costs Adj', 'Insured Damages', 'Insured Damages Adj', 'Total Damages','Total Damages Adj']
for col in num_cols_outliers:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# ## Frecuencia y distribución de variables categóricas
#
# Explorar y analizar la distribución de variables categóricas examinando sus conteos de frecuencia o proporciones.

# %% [markdown]
# Objetivo: identificar categorías que están significativamente sobrerrepresentadas o subrepresentadas en el conjunto de datos.

# %% [markdown]
# #### Definir seaborn palette Spectral

# %%
# Set Spectral palette
sns.set_palette('Spectral')
sns.set(font_scale=0.6)
palette_color = sns.color_palette('Spectral')

# %% [markdown]
# ### Variables categóricas por niveles según clasificación de dataset

# %%
categ_lvl1 = ['Disaster Subgroup', 'Disaster Type','Disaster Subtype']
categ_lvl2_geo = ['Country','Region', 'Continent', 'Location', 'River Basin']
categ_lvl2_geoloc = ['Latitude', 'Longitude'] # Estas pertenecen a la anterior pero es mejor separarlas debido a su carácter más específico
num_lvl2_temp = ['Local Time', 'Start Year','Start Month', 'Start Day', 'End Year', 'End Month', 'End Day'] # Son objects, evaluar si es necesario convertir a datetimes numéricas
categ_lvl2_time = ['Local Time']
categ_lvl2_fis = ['Origin', 'Associated Dis','Associated Dis2', 'Dis Mag Scale']
categ_lvl2_status = ['AID Contribution', 'OFDA Response', 'Appeal','Declaration']
# categ_lvl3_orgs = [] Se borraron los Adm Level y Admin Codes
num_lvl3_human_impact = ['Total Deaths', 'No Injured', 'No Affected', 'No Homeless', 'Total Affected']
num_lvl3_economic_impact = ['Reconstruction Costs', 'Reconstruction Costs Adj', 'Insured Damages', 'Insured Damages Adj', 'Total Damages', 'Total Damages Adj']

# %% [markdown]
# ### Nivel 1 Evento de desastre

# %% [markdown]
# #### Value counts y unique values

# %%
df['Disaster Subgroup'].value_counts()
# Out:
# Disaster Subgroup
# Hydrological         6612
# Meteorological       5235
# Geophysical          1912
# Biological           1614
# Climatological       1262
# Extra-terrestrial       1
# Name: count, dtype: int64

# %%
df['Disaster Subgroup'].unique()
# Out:
# array(['Climatological', 'Geophysical', 'Meteorological', 'Hydrological',
#        'Biological', 'Extra-terrestrial'], dtype=object)

# %%
df['Disaster Type'].value_counts()
# Out:
# Disaster Type
# Flood                    5808
# Storm                    4618
# Earthquake               1597
# Epidemic                 1518
# Landslide                 804
# Drought                   803
# Extreme temperature       616
# Wildfire                  456
# Volcanic activity         270
# Insect infestation         95
# Mass movement (dry)        45
# Glacial lake outburst       3
# Fog                         1
# Impact                      1
# Animal accident             1
# Name: count, dtype: int64

# %%
df['Disaster Type'].unique()
# Out:
# array(['Drought', 'Earthquake', 'Volcanic activity',
#        'Mass movement (dry)', 'Storm', 'Flood', 'Epidemic', 'Landslide',
#        'Wildfire', 'Extreme temperature', 'Fog', 'Insect infestation',
#        'Impact', 'Animal accident', 'Glacial lake outburst'], dtype=object)

# %%
df['Disaster Subtype'].value_counts()
# Out:
# Disaster Subtype
# Riverine flood                      2657
# Tropical cyclone                    2475
# Ground movement                     1540
# Convective storm                    1180
# Flash flood                          822
# Drought                              802
# Bacterial disease                    781
# Landslide                            587
# Viral disease                        544
# Forest fire                          314
# Cold wave                            310
# Ash fall                             248
# Heat wave                            229
# Extra-tropical storm                 148
# Avalanche                            122
# Land fire (Brush, Bush, Pasture)      92
# Coastal flood                         85
# Mudslide                              79
# Severe winter conditions              77
# Locust                                67
# Tsunami                               57
# Parasitic disease                     51
# ...

# %%
df['Disaster Subtype'].unique()
# Out:
# array(['Drought', 'Ground movement', 'Ash fall', 'Rockfall',
#        'Tropical cyclone', nan, 'Bacterial disease', 'Landslide',
#        'Avalanche', 'Forest fire', 'Riverine flood', 'Convective storm',
#        'Viral disease', 'Mudslide', 'Tsunami', 'Heat wave',
#        'Land fire (Brush, Bush, Pasture)', 'Coastal flood', 'Cold wave',
#        'Flash flood', 'Parasitic disease', 'Locust', 'Worms',
#        'Severe winter conditions', 'Grasshopper', 'Subsidence',
#        'Extra-tropical storm', 'Lava flow', 'Pyroclastic flow'],
#       dtype=object)

# %% [markdown]
# ### Visualizaciones Nivel 1 eventos de desastres

# %%
for col in categ_lvl1:
    sns.countplot(x=col, data=df)
    plt.title(f'Countplot de {col}')
    plt.xticks(rotation=75)
    plt.show()

# %% [markdown]
# ### Nivel 2 País(es)

# %% [markdown]
# ### Variables geográficas:
# Distribución geográfica: Regiones, Continentes, Localidades

# %% [markdown]
# #### Value counts y uniques geográficos

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America (the)    1131
# China                              994
# India                              760
# Philippines (the)                  684
# Indonesia                          610
#                                   ...
# Qatar                                1
# Saint Barthï¿½lemy                   1
# Saint Martin (French Part)           1
# Sint Maarten (Dutch part)            1
# Isle of Man                          1
# Name: count, Length: 228, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['Cabo Verde', 'India', 'Guatemala', 'Canada', 'Comoros (the)',
#        'Bangladesh', 'Chile', 'Colombia', 'Belgium', 'Hong Kong', 'China',
#        'France', 'Haiti', 'Indonesia', 'Burkina Faso', 'Costa Rica',
#        'Algeria', 'Gambia (the)', 'Guinea-Bissau', 'Anguilla',
#        'Germany Fed Rep', 'Ecuador', 'Bahamas (the)', 'Cuba', 'Egypt',
#        'Bulgaria', 'Guadeloupe', 'Greece', 'Dominica',
#        'Dominican Republic (the)', 'Belize', 'Fiji', 'Honduras', 'Ghana',
#        'Australia', 'Cook Islands (the)', 'Argentina', 'Azores Islands',
#        'Bermuda', 'Brazil', 'Antigua and Barbuda', 'Switzerland',
#        'Austria',
#        'United Kingdom of Great Britain and Northern Ireland (the)',
#        'Cyprus', 'Spain', 'Afghanistan', 'Netherlands Antilles',
#        'Barbados', 'Ethiopia', 'Albania', 'Guam', 'Grenada',
#        'Bolivia (Plurinational State of)', 'Botswana', 'American Samoa',
# ...

# %%
df['Region'].value_counts()
# Out:
# Region
# Southern Asia                2118
# South-Eastern Asia           2034
# Eastern Asia                 1840
# South America                1371
# Northern America             1286
# Eastern Africa               1221
# Central America               845
# Western Africa                829
# Southern Europe               669
# Caribbean                     642
# Eastern Europe                556
# Western Europe                545
# Western Asia                  524
# Middle Africa                 452
# Northern Africa               356
# Australia and New Zealand     298
# Melanesia                     261
# Southern Africa               221
# Northern Europe               220
# Central Asia                  144
# Polynesia                      95
# Russian Federation             64
# Micronesia                     45
# Name: count, dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['Western Africa', 'Southern Asia', 'Central America',
#        'Northern America', 'Eastern Africa', 'South America',
#        'Western Europe', 'Eastern Asia', 'Caribbean',
#        'South-Eastern Asia', 'Northern Africa', 'Eastern Europe',
#        'Southern Europe', 'Melanesia', 'Australia and New Zealand',
#        'Polynesia', 'Northern Europe', 'Western Asia', 'Micronesia',
#        'Southern Africa', 'Middle Africa', 'Russian Federation',
#        'Central Asia'], dtype=object)

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Asia        6660
# Americas    4144
# Africa      3079
# Europe      2054
# Oceania      699
# Name: count, dtype: int64

# %%
df['Continent'].unique()
# Out:
# array(['Africa', 'Asia', 'Americas', 'Europe', 'Oceania'], dtype=object)

# %%
df['Location'].value_counts()
# Out:
# Location
# North                                                                                                                                    46
# South                                                                                                                                    38
# Countrywide                                                                                                                              34
# Central                                                                                                                                  30
# Taiwan Sheng province                                                                                                                    23
#                                                                                                                                          ..
# ...

# %%
df['Location'].unique()
# Out:
# array(['Countrywide', 'Bengal', 'Quezaltenango, San Marcos', ...,
#        'Chikoma, Mbande, Mzigawa, Chipanji, Mlawe, Eastern, Luapula, Lusaka, Southern',
#        'Sjenica and Brodarevo Novi Pazar Municipality; Novi Pazar Municipality (Sumadija and Western Serbia Region, south-western Serbia)',
#        'Malakal (Upper Nile state)'], dtype=object)

# %%
df['River Basin'].value_counts()
# Out:
# River Basin
# Yangtze river                                                                             9
# Mekong river                                                                              9
# Shabelle river                                                                            6
# Yangtze                                                                                   5
# Brahmaputra                                                                               4
#                                                                                          ..
# Kadzi, Kadzurure, Musengezi, Chihuri, Tsoro, Mataure, Utete, Muringazuva, Hambe, Dande    1
# Song Con, Thai Binh                                                                       1
# Kon, Lai Giang and La Tinh                                                                1
# Guachi, Capazon                                                                           1
# ...

# %%
df['River Basin'].unique()
# Out:
# array([nan, 'Changiyang river', 'Lannemazan', ..., 'Jubba River',
#        'Talanda River', 'Trnavica River'], dtype=object)

# %% [markdown]
# ### Visualizaciones Nivel 2: variables geográficas

# %% [markdown]
# #### Countplots

# %%
geo_cols = ['Region', 'Continent']
# Realizar countplot solo con Region y Continent,
# No Country ni Location: demasiados resultados

for col in geo_cols:
    sns.countplot(x=col, data=df)
    plt.title(f'Countplot de {col}')
    plt.xticks(rotation=75)
    plt.show()

# %% [markdown]
# #### Pie Charts

# %%
geo_cols = ['Continent']

for col in geo_cols:
    category_counts = df[col].value_counts()
    labels = category_counts.index
    sizes = category_counts.values

    plt.pie(x=sizes, labels=labels, colors=palette_color, autopct='%.0f%%')
    plt.title(f'Gráfica de Pie de {col}')
    plt.legend(fontsize=6)
    plt.show()

# %% [markdown]
# ### Variables características físicas:
# Distribución de: Origen, Desastres Asociados 1 y 2, Escala de Magnitud de Desastre

# %% [markdown]
# ### Visualizaciones Nivel 2: características físicas
