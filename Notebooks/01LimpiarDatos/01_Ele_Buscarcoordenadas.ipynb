# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('../../Data/02ParaLimpiar/02desastres_definitivo.csv', delimiter=';', encoding='utf-8')
df.head(2)
# Out:
#           Dis No  Year   Seq Disaster Subgroup Disaster Type Disaster Subtype  \
# 0  1900-9002-CPV  1900  9002    Climatological       Drought          Drought
# 1  1900-9001-IND  1900  9001    Climatological       Drought          Drought
#
#       Country  ISO          Region Continent  ... Longitude Start Year  \
# 0  Cabo Verde  CPV  Western Africa    Africa  ...       NaN       1900
# 1       India  IND   Southern Asia      Asia  ...       NaN       1900
#
#   Start Month  Start Day End Year End Month End Day  Total Deaths  \
# 0         NaN        NaN     1900       NaN     NaN       11000.0
# 1         NaN        NaN     1900       NaN     NaN     1250000.0
#
#    Total Affected  Total Damages Adj
# 0             NaN                NaN
# 1             NaN                NaN
#
# [2 rows x 26 columns]

# %%
filter = df['Disaster Type'] == 'Earthquake'
df_earthquake = df[filter]
df_earthquake.head(2)
# Out:
#           Dis No  Year  Seq Disaster Subgroup Disaster Type Disaster Subtype  \
# 2  1902-0012-GTM  1902   12       Geophysical    Earthquake  Ground movement
# 9  1905-0003-IND  1905    3       Geophysical    Earthquake  Ground movement
#
#      Country  ISO           Region Continent  ... Longitude Start Year  \
# 2  Guatemala  GTM  Central America  Americas  ...       -91       1902
# 9      India  IND    Southern Asia      Asia  ...     76.16       1905
#
#   Start Month  Start Day End Year End Month End Day  Total Deaths  \
# 2         4.0       18.0     1902       4.0    18.0        2000.0
# 9         4.0        4.0     1905       4.0     4.0       20000.0
#
#    Total Affected  Total Damages Adj
# 2             NaN           843726.0
# 9             NaN           812477.0
#
# [2 rows x 26 columns]

# %%
df_earthquake[['Latitude', 'Longitude']].isnull().sum()
# Out:
# Latitude     50
# Longitude    50
# dtype: int64

# %%
filter = df_earthquake['Latitude'].isnull() | df_earthquake['Longitude'].isnull()

# Filtramos el dataframe para obtener solo las filas con valores nan en esas columnas
df_earthquake_nan= df_earthquake[filter]
df_earthquake_nan[['Longitude','Latitude','Location', 'Country']].head(50)
# Out:
#       Longitude Latitude                                           Location  \
# 92          NaN      NaN                                            Plovdiv
# 146         NaN      NaN                             Southern China, Yunnan
# 281         NaN      NaN                                                NaN
# 719         NaN      NaN                                       Camaron area
# 789         NaN      NaN                                         East Timor
# 864         NaN      NaN                                                NaN
# 934         NaN      NaN                                                NaN
# 964         NaN      NaN                                                NaN
# 1029        NaN      NaN                                                NaN
# 1030        NaN      NaN                                                NaN
# 1044        NaN      NaN                                                NaN
# 1105        NaN      NaN                                              Hawai
# 1212        NaN      NaN                             Onagawa, Honshu Island
# 1215        NaN      NaN                                             Hawaii
# 1228        NaN      NaN                                         Nationwide
# 1702        NaN      NaN                                             Friuli
# 1923        NaN      NaN                         Beni (North Kivu province)
# 2717        NaN      NaN                                 Ternate (Moluccas)
# 2873        NaN      NaN                                  Avellino, Potenza
# 3613        NaN      NaN                                             Taipai
# 3628        NaN      NaN                                  Eastern Venezuela
# 4045        NaN      NaN                                         Shufu area
# 4789        NaN      NaN                                          Moyo area
# 7091        NaN      NaN                                            Kayseri
# 7209        NaN      NaN                                           Marmaris
# 13901       NaN      NaN                           Yangbi (Yunnan province)
# 13902       NaN      NaN                                    Xinjiang region
# 13937       NaN      NaN  Huehuetenango, Quetzaltenango, Quich�, San Mar...
# 14182       NaN      NaN                                       Surigao city
# 14291       NaN      NaN  Casamicciola Terme, Lacco Ameno (Ischia Isl.),...
# 14301       NaN      NaN  Karamyk, Jekendi, Kara-Teyit, Chuluk, Shibee v...
# 14368       NaN      NaN          Atsuma village, Abira, Sapporo (Hokkaido)
# 14718       NaN      NaN                                             Bodrum
# 15019       NaN      NaN                                      Mila province
# 15100       NaN      NaN  Chuxiong Yi Autonomous Prefecture, Yunnan Prov...
# 15102       NaN      NaN  Jiangcheng Hani and Yi Autonomous County (Yunn...
# 15137       NaN      NaN         Lijiang, Ninglang Yi, Yulong Naxi (Yunnan)
# 15268       NaN      NaN                        Auvergne-Rh�ne-Alpes region
# 15634       NaN      NaN  Selayar Islands Regency (South Sulawesi Provin...
# 15659       NaN      NaN      Esfahan, Kohgiluyeh and Boyer-Ahmad provinces
# 15710       NaN      NaN                                       Piura region
# 15737       NaN      NaN                                    Maluku Province
# 16145       NaN      NaN             Tadjikobod district (Douchanb� region)
# 16262       NaN      NaN                              Ljubinje and Capljina
# 16314       NaN      NaN  Mentawai Islands Regency, (West Sumatra Province)
# 16326       NaN      NaN                                              Papua
# 16489       NaN      NaN  Lakki Marwat District (southern Khyber Pakhtun...
# 16585       NaN      NaN               Khoy City (West Azerbaijan Province)
# 16610       NaN      NaN                                          Northwest
# 16616       NaN      NaN              Yesilyurt District (Malatya province)
#
#                                       Country
# 92                                   Bulgaria
# 146                                     China
# 281                                     Chile
# 719                                      Cuba
# 789                                 Indonesia
# 864                                   Romania
# 934                                   Romania
# 964                                   Romania
# 1029                                  Romania
# 1030                                  Romania
# 1044               Iran (Islamic Republic of)
# 1105           United States of America (the)
# 1212                                    Japan
# 1215           United States of America (the)
# 1228                        Philippines (the)
# 1702                                    Italy
# 1923   Congo (the Democratic Republic of the)
# 2717                                Indonesia
# 2873                                    Italy
# 3613               Taiwan (Province of China)
# 3628       Venezuela (Bolivarian Republic of)
# 4045                                    China
# 4789                                   Uganda
# 7091                                   Turkey
# 7209                                   Turkey
# 13901                                   China
# 13902                                   China
# 13937                               Guatemala
# 14182                       Philippines (the)
# 14291                                   Italy
# 14301                              Kyrgyzstan
# 14368                                   Japan
# 14718                                  Turkey
# 15019                                 Algeria
# 15100                                   China
# 15102                                   China
# 15137                                   China
# 15268                                  France
# 15634                               Indonesia
# 15659              Iran (Islamic Republic of)
# 15710                                    Peru
# 15737                               Indonesia
# 16145                              Tajikistan
# 16262                  Bosnia and Herzegovina
# 16314                               Indonesia
# 16326                               Indonesia
# 16489                                Pakistan
# 16585              Iran (Islamic Republic of)
# 16610                    Syrian Arab Republic
# 16616                                  Turkey

# %%
address = 'Atacama, Chile'
geolocator = Nominatim(user_agent='MozillaFirefox', timeout=10000)
location = geolocator.geocode(address)
print(location.latitude, location.longitude)
# Out:
# -27.5571783 -70.0156882

# %%
for i, row in df_earthquake_nan.iterrows():
    if pd.isnull(row['Location']):
        location = geolocator.geocode(row['Country'])
    else:
        location = geolocator.geocode(row['Location'])
    if location:
        df_earthquake_nan.loc[i, 'Latitude'] = location.latitude
        df_earthquake_nan.loc[i, 'Longitude'] = location.longitude

# %%
df_earthquake_nan[['Latitude', 'Longitude']].isnull().sum()
# Out:
# Latitude     15
# Longitude    15
# dtype: int64

# %%
df_earthquake_nan[['Latitude', 'Longitude']].head(50)
# Out:
#         Latitude   Longitude
# 92     42.141854    24.74993
# 146    27.281937  100.849778
# 281   -31.761336   -71.31877
# 719    40.438671    -3.67614
# 789    -8.744317  126.063482
# 864    45.985213   24.685923
# 934    45.985213   24.685923
# 964    45.985213   24.685923
# 1029   45.985213   24.685923
# 1030   45.985213   24.685923
# 1044   32.647531   54.564352
# 1105   19.593801  -155.42837
# 1212         NaN         NaN
# 1215   19.593801  -155.42837
# 1228   51.538246   -1.776962
# 1702  -31.442787  -64.198345
# 1923         NaN         NaN
# 2717   -3.269905   126.00704
# 2873   41.088792   15.596681
# 3613    25.03752   121.56368
# 3628   14.644719  121.088394
# 4045         NaN         NaN
# 4789    3.669152    31.70809
# 7091   38.658223   35.554637
# 7209   36.852255   28.274266
# 13901  25.673455   99.957079
# 13902    23.8672     109.052
# 13937        NaN         NaN
# 14182   9.790503   125.49357
# 14291        NaN         NaN
# 14301        NaN         NaN
# 14368        NaN         NaN
# 14718  37.034399   27.430651
# 15019  36.250214    6.165216
# 15100  25.432036  101.704785
# 15102  22.586893  101.861588
# 15137        NaN         NaN
# 15268        NaN         NaN
# 15634        NaN         NaN
# 15659        NaN         NaN
# 15710  -5.197138  -80.626724
# 15737  -3.694344  128.182613
# 16145        NaN         NaN
# 16262        NaN         NaN
# 16314  -1.358782   98.895005
# 16326  -5.681607  144.248908
# 16489        NaN         NaN
# 16585  38.550434    44.95354
# 16610   6.377525   10.386417
# 16616        NaN         NaN

# %%
address = 'Honshu Island, Japan'
geolocator = Nominatim(user_agent='MozillaFirefox', timeout=10000)
location = geolocator.geocode(address)
print(location.latitude, location.longitude)
# Out:
# 37.490012 139.8356621412412

# %%
address = 'Beni, North Kivu, Congo'
geolocator = Nominatim(user_agent='MozillaFirefox', timeout=10000)
location = geolocator.geocode(address)
print(location.latitude, location.longitude)
# Out:
# 0.47606519999999997 29.189300190040722

# %%
address = 'Shufu, China'
geolocator = Nominatim(user_agent='MozillaFirefox', timeout=10000)
location = geolocator.geocode(address)
print(location.latitude, location.longitude)
# Out:
# 39.3742218 75.859333
