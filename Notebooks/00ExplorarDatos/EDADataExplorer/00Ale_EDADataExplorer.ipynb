# %% [markdown]
# # Exploración de datos Natural Disasters Data Explorer

# %% [markdown]
# Usando dataset natural-disasters-data-explorer.csv

# %% [markdown]
# Objetivos:
# Cargar dataset, shape, info, describe, columns, nulls

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../../Data/00Complementarios/NaturalDisastersDataExplorer/natural-disasters-data-explorer.csv', encoding='utf-8', delimiter=';', engine='python')

# %% [markdown]
# ### Muestras head, slice 500:520 y tail

# %%
df.head(5)
# Out:
#   Number of deaths from drought,Number of people injured from drought,Number of people affected from drought,Number of people left homeless from drought,Number of total people affected by drought,Reconstruction costs from drought,Insured damages against drought,Total economic damages from drought,Death rates from drought,Injury rates from drought,"Number of people affected by drought per 100,000",Homelessness rate from drought,"Total number of people affected by drought per 100,000",Number of deaths from earthquakes,Number of people injured from earthquakes,Number of people affected by earthquakes,Number of people left homeless from earthquakes,Number of total people affected by earthquakes,Reconstruction costs from earthquakes,Insured damages against earthquakes,Total economic damages from earthquakes,Death rates from earthquakes,Injury rates from earthquakes,"Number of people affected by earthquakes per 100,000",Homelessness rate from earthquakes,"Total number of people affected by
# ...

# %%
df[500:520]
# Out:
#                      Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 500                 Schweiz   2.46      9.56          25.73           14.57
# 501                 Estland   2.42      7.23          33.46           18.03
# 502                  Israel   2.39      6.41          37.26           19.54
# 503                Norwegen   2.28      8.58          26.51           14.08
# 504                 Ägypten   2.26      4.72          47.89           20.99
# 505                Finnland   2.26      8.19          27.59           15.85
# 506                Singapur   2.24      7.82          28.62           14.05
# 507                Schweden   2.22      7.97          27.89           15.53
# 508  Ver. Arabische Emirate   1.84      5.93          31.08           10.36
# 509                 Bahrain   1.76      4.27          41.21           12.88
# 510                Kiribati   1.73      3.05          56.68           41.19
# ...

# %%
df.tail(5)
# Out:
#             Region   WRI  Exposure  Vulnerability  Susceptibility  \
# 1912       Grenada  1.42      3.13          45.39           24.54
# 1913      Barbados  1.32      3.46          38.26           18.20
# 1914  Saudi Arabia  1.14      2.93          38.96           14.80
# 1915         Malta  0.60      1.65          36.25           15.97
# 1916         Qatar  0.08      0.28          28.18            9.68
#
#       Lack of Coping Capabilities  Lack of Adaptive Capacities  Year  \
# 1912                        68.82                        42.82  2016
# 1913                        50.29                        46.29  2016
# 1914                        65.01                        37.07  2016
# 1915                        59.33                        33.44  2016
# 1916                        43.94                        30.93  2016
#
#      Exposure Category WRI Category Vulnerability Category  \
# 1912          Very Low     Very Low                 Medium
# ...

# %% [markdown]
# ## shape, info y dtypes

# %%
df.shape
# Resultado: 1917 filas y 12 columnas)
# Out:
# (1917, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Region                       1917 non-null   object
#  1   WRI                          1917 non-null   float64
#  2   Exposure                     1917 non-null   float64
#  3   Vulnerability                1917 non-null   float64
#  4   Susceptibility               1917 non-null   float64
#  5   Lack of Coping Capabilities  1917 non-null   float64
#  6   Lack of Adaptive Capacities  1916 non-null   float64
#  7   Year                         1917 non-null   int64
#  8   Exposure Category            1917 non-null   object
#  9   WRI Category                 1916 non-null   object
#  10  Vulnerability Category       1913 non-null   object
#  11  Susceptibility Category      1917 non-null   object
# dtypes: float64(6), int64(1), object(5)
# ...

# %%
df.dtypes
# Out:
# Region                          object
# WRI                            float64
# Exposure                       float64
# Vulnerability                  float64
# Susceptibility                 float64
# Lack of Coping Capabilities    float64
# Lack of Adaptive Capacities    float64
# Year                             int64
# Exposure Category               object
# WRI Category                    object
# Vulnerability Category          object
# Susceptibility Category         object
# dtype: object

# %% [markdown]
# ## Columnas

# %%
df.columns
# Out:
# Index(['Region', 'WRI', 'Exposure', 'Vulnerability', 'Susceptibility',
#        'Lack of Coping Capabilities', 'Lack of Adaptive Capacities', 'Year',
#        'Exposure Category', 'WRI Category', 'Vulnerability Category',
#        'Susceptibility Category'],
#       dtype='object')

# %% [markdown]
# ### Columnas con valores numéricos: 7

# %% [markdown]
# WRI                            float64
# Exposure                       float64
# Vulnerability                  float64
# Susceptibility                 float64
# Lack of Coping Capabilities    float64
# Lack of Adaptive Capacities    float64
# Year                             int64

# %% [markdown]
# ### Columnas con variables categóricas: 5

# %% [markdown]
# Region, Exposure Category, WRI Category, Vulnerability Category, Susceptibility Category

# %% [markdown]
# ## Estadísticas básicas

# %%
df.describe(include='number')
# Out:
#                WRI     Exposure  Vulnerability  Susceptibility  \
# count  1917.000000  1917.000000    1917.000000     1917.000000
# mean      7.551763    15.388336      48.075759       30.739431
# std       5.553257    10.240135      13.835666       15.667030
# min       0.020000     0.050000      14.310000        8.260000
# 25%       3.740000    10.160000      37.040000       17.790000
# 50%       6.520000    12.760000      47.100000       25.400000
# 75%       9.400000    16.450000      60.060000       42.640000
# max      56.710000    99.880000      76.470000       70.830000
#
#        Lack of Coping Capabilities  Lack of Adaptive Capacities         Year
# count                  1917.000000                  1916.000000  1917.000000
# mean                     70.438289                    43.090511  2016.049557
# std                      15.038854                    13.551156     3.182045
# min                      31.590000                    11.160000  2011.000000
# ...

# %%
df.describe(include='object')
# Out:
#          Region Exposure Category WRI Category Vulnerability Category  \
# count      1917              1917         1916                   1913
# unique      306                 5            5                      5
# top     Vanuatu          Very Low     Very Low               Very Low
# freq         11               393          393                    386
#
#        Susceptibility Category
# count                     1917
# unique                       5
# top                   Very Low
# freq                       390

# %% [markdown]
# ## Valores faltantes

# %%
df.isnull().sum()
# Out:
# Region                         0
# WRI                            0
# Exposure                       0
# Vulnerability                  0
# Susceptibility                 0
# Lack of Coping Capabilities    0
# Lack of Adaptive Capacities    1
# Year                           0
# Exposure Category              0
# WRI Category                   1
# Vulnerability Category         4
# Susceptibility Category        0
# dtype: int64

# %%
df.isnull()
# Out:
#       Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 0      False  False     False          False           False
# 1      False  False     False          False           False
# 2      False  False     False          False           False
# 3      False  False     False          False           False
# 4      False  False     False          False           False
# ...      ...    ...       ...            ...             ...
# 1912   False  False     False          False           False
# 1913   False  False     False          False           False
# 1914   False  False     False          False           False
# 1915   False  False     False          False           False
# 1916   False  False     False          False           False
#
#       Lack of Coping Capabilities  Lack of Adaptive Capacities   Year  \
# 0                           False                        False  False
# 1                           False                        False  False
# ...

# %% [markdown]
# ## Bucle for para .unique y .value_counts por columna

# %%
# Bucle For para obtener value counts por cada columna
columns = ['Region', 'WRI', 'Exposure', 'Vulnerability', 'Susceptibility',
           'Lack of Coping Capabilities', 'Lack of Adaptive Capacities', 'Year',
           'Exposure Category', 'WRI Category', 'Vulnerability Category',
           'Susceptibility Category']

for column in columns:
    print(f"Columna: {column}")
    print("Value Counts:")
    print(df[column].value_counts())
    print()
# Out:
# Columna: Region
# Value Counts:
# Vanuatu                          11
# Lesotho                          11
# Turkmenistan                     11
# Eritrea                          11
# Peru                             11
#                                  ..
# Zentralafrik. Republik            1
# Ver. Arabische Emirate            1
# Eswatini                          1
# T. f. Yugo. Rep. of Macedonia     1
# Korea Republic of 4.59            1
# Name: Region, Length: 306, dtype: int64
#
# Columna: WRI
# Value Counts:
# 3.56     7
# 3.46     7
# 7.84     6
# 3.42     6
# 6.44     6
#         ..
# 10.44    1
# 10.42    1
# 10.33    1
# 9.66     1
# 0.60     1
# Name: WRI, Length: 1026, dtype: int64
#
# Columna: Exposure
# Value Counts:
# 12.25    14
# 9.55     13
# 13.84    13
# 6.41     13
# 11.66    12
#          ..
# 17.59     1
# 12.57     1
# 14.23     1
# 11.46     1
# 30.82     1
# Name: Exposure, Length: 807, dtype: int64
#
# Columna: Vulnerability
# Value Counts:
# ...

# %% [markdown]
# ## Bucle for para .unique por columna

# %%
# Bucle For para obtener value counts y unique values por cada columna
columns = ['Region', 'WRI', 'Exposure', 'Vulnerability', 'Susceptibility',
           'Lack of Coping Capabilities', 'Lack of Adaptive Capacities', 'Year',
           'Exposure Category', 'WRI Category', 'Vulnerability Category',
           'Susceptibility Category']

for column in columns:
    print(f"Columna: {column}")
    print("Unique Values:")
    print(df[column].unique())
    print()
# Out:
# Columna: Region
# Unique Values:
# ['Vanuatu' 'Tonga' 'Philippinen' 'Salomonen' 'Guatemala' 'Bangladesch'
#  'Timor-Leste' 'Costa Rica' 'Kambodscha' 'El Salvador' 'Nicaragua'
#  'Papua-Neuguinea' 'Madagaskar' 'Brunei Darussalam' 'Afghanistan' 'Niger'
#  'Gambia' 'Bhutan' 'Fidschi' 'Guinea-Bissau' 'Jamaika' 'Tschad' 'Honduras'
#  'Dominikanische Republik' 'Chile' 'Mauritius' 'Senegal' 'Indonesien'
#  'Burkina Faso' 'Burundi' 'Mali' 'Haiti' 'Sierra Leone' 'Vietnam' 'Japan'
#  'Benin' 'Togo' 'Kamerun' 'Albanien' 'Mosambik' 'Mauretanien' 'Simbabwe'
#  'Guinea' 'Kap Verde' 'Usbekistan' 'Ghana' 'Suriname' 'Sudan' 'Liberia'
#  'Nigeria' 'Elfenbeinküste' 'Guyana' 'Malawi' 'Ecuador' 'Ruanda'
#  'Tansania' 'Myanmar' 'Kirgisistan' 'Sambia' 'Äthiopien' 'Algerien'
#  'Angola' 'Samoa' 'Lesotho' 'Sri Lanka' 'Pakistan' 'Kenia' 'Kongo'
#  'Niederlande' 'Panama' 'Indien' 'Uganda' 'Tadschikistan' 'Swasiland'
#  'Peru' 'Eritrea' 'Zentralafrikanische Republik' 'Marokko' 'Griechenland'
# ...

# %% [markdown]
# ## Detección y exploración de outliers

# %%
outlier_columns = ['WRI', 'Exposure', 'Vulnerability', 'Susceptibility', 'Lack of Coping Capabilities',
                   'Lack of Adaptive Capacities']
outliers = {}
for column in outlier_columns:
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    column_outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    outliers[column] = column_outliers

# Explorar outliers
for column, outlier_data in outliers.items():
    print(f"Outliers for column: {column}")
    print(outlier_data)
    print()
# Out:
# Outliers for column: WRI
#                Region    WRI  Exposure  Vulnerability  Susceptibility  \
# 0             Vanuatu  32.00     56.33          56.81           37.14
# 1               Tonga  29.08     56.04          51.90           28.94
# 2         Philippinen  24.32     45.09          53.93           34.99
# 3           Salomonen  23.51     36.40          64.60           44.11
# 4           Guatemala  20.88     38.42          54.35           35.36
# ...               ...    ...       ...            ...             ...
# 1747            Tonga  29.33     55.27          53.08           28.66
# 1748      Philippines  26.70     52.46          50.90           31.83
# 1749        Guatemala  19.88     36.30          54.76           35.82
# 1750       Bangladesh  19.17     31.70          60.48           38.23
# 1751  Solomon Islands  19.14     29.98          63.83           44.01
#
#       Lack of Coping Capabilities  Lack of Adaptive Capacities  Year  \
# ...

# %% [markdown]
# ## Rankings por columnas

# %%
# Rankings por columna
rankings = {}
for column in columns:
    if df[column].dtype != 'object':
        rankings[column] = df[column].rank(ascending=False)

# Explorar rankings
for column, rank_data in rankings.items():
    print(f"Rankings for column: {column}")
    print(rank_data)
    print()
# Out:
# Rankings for column: WRI
# 0         11.0
# 1         20.0
# 2         37.0
# 3         39.0
# 4         54.0
#          ...
# 1912    1867.0
# 1913    1873.5
# 1914    1885.0
# 1915    1904.0
# 1916    1915.0
# Name: WRI, Length: 1917, dtype: float64
#
# Rankings for column: Exposure
# 0         22.0
# 1         23.0
# 2         49.0
# 3         95.0
# 4         81.0
#          ...
# 1912    1870.5
# 1913    1862.5
# 1914    1882.5
# 1915    1902.5
# 1916    1913.5
# Name: Exposure, Length: 1917, dtype: float64
#
# Rankings for column: Vulnerability
# 0        576.0
# 1        716.5
# 2        656.0
# 3        317.0
# 4        648.5
#          ...
# 1912    1063.0
# 1913    1380.0
# 1914    1355.5
# 1915    1476.0
# 1916    1762.0
# Name: Vulnerability, Length: 1917, dtype: float64
#
# Rankings for column: Susceptibility
# 0        571.0
# 1        800.5
# 2        620.0
# 3        458.0
# 4        608.0
#          ...
# 1912     998.0
# 1913    1400.0
# 1914    1740.5
# ...

# %% [markdown]
# # Visualizaciones de outliers

# %% [markdown]
# ## Box plots para columnas numéricas

# %%
numerical_columns = ['WRI', 'Exposure', 'Vulnerability', 'Susceptibility', 'Lack of Coping Capabilities', 'Lack of Adaptive Capacities']
for column in numerical_columns:
    plt.figure()
    plt.boxplot(df[column])
    plt.title(f"Box Plot of {column}")
    plt.show()

# %% [markdown]
# ### Barplots para columnas categóricas

# %%
categorical_columns = ['Region', 'Exposure Category', 'WRI Category', 'Vulnerability Category', 'Susceptibility Category']

for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=column, data=df)
    plt.title(f"Count Plot of {column}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Bar plots

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 8))
    df[column].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.title(f"Pie Chart of {column}")
    plt.ylabel('')
    plt.show()

# %% [markdown]
# ### Bar plots

# %%
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    df[column].value_counts().plot(kind='bar', stacked=True)
    plt.title(f"Stacked Bar Plot of {column}")
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Donut plots

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 8))
    df[column].value_counts().plot(kind='pie', autopct='%1.1f%%', wedgeprops=dict(width=0.3))
    plt.title(f"Donut Plot of {column}")
    plt.ylabel('')
    plt.show()

# %% [markdown]
# ### Heatmaps

# %%
for column in categorical_columns:
    crosstab = pd.crosstab(index=df[column], columns='count')
    plt.figure(figsize=(8, 6))
    sns.heatmap(crosstab, annot=True, cmap='Blues', cbar=False)
    plt.title(f"Heatmap de {column}")
    plt.xlabel('')
    plt.ylabel('')
    plt.show()

# %% [markdown]
# # Análisis Bivariante

# %%
# Bivariate EDA
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Exposure', y='WRI')
plt.title('Scatter Plot de Exposure vs. WRI')
plt.xlabel('Exposure')
plt.ylabel('WRI')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Vulnerability Category', y='WRI')
plt.title('Box Plot de Vulnerability Category vs. WRI')
plt.xlabel('Vulnerability Category')
plt.ylabel('WRI')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Region', y='WRI')
plt.title('Bar Plot de Region vs. WRI')
plt.xlabel('Region')
plt.ylabel('WRI')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\AleEng\AppData\Local\Temp\ipykernel_1668\1495929767.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
