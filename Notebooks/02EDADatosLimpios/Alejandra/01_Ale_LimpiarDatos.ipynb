# %% [markdown]
# # Exploración de datos básica

# %% [markdown]
# Usando dataset 02desastres_paralimpiar.csv tras haber quitado columnas

# %% [markdown]
# Objetivos:
# * Cargar dataset
# * Estadísticas básicas. shape, info, describe dtypes numéricos y categóricos, columns, nulls
# * Categorización por niveles
# * Visualizaciones boxplot

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cargar datos

# %%
df = pd.read_csv('../../../Data/02ParaLimpiar/02desastres_paralimpiar.csv', encoding='latin-1', delimiter=';', engine='python')
# encoding='utf8' da problemas
# dejar engine='python' para evitar advertencias

# %% [markdown]
# ### Muestras head, slice 500:520 y tail

# %%
df.head(5)
# Out:
#           Dis No  Year   Seq Disaster Subgroup      Disaster Type  \
# 0  1900-9002-CPV  1900  9002    Climatological            Drought
# 1  1900-9001-IND  1900  9001    Climatological            Drought
# 2  1902-0012-GTM  1902    12       Geophysical         Earthquake
# 3  1902-0003-GTM  1902     3       Geophysical  Volcanic activity
# 4  1902-0010-GTM  1902    10       Geophysical  Volcanic activity
#
#   Disaster Subtype     Country  ISO           Region Continent  ...  \
# 0          Drought  Cabo Verde  CPV   Western Africa    Africa  ...
# 1          Drought       India  IND    Southern Asia      Asia  ...
# 2  Ground movement   Guatemala  GTM  Central America  Americas  ...
# 3         Ash fall   Guatemala  GTM  Central America  Americas  ...
# 4         Ash fall   Guatemala  GTM  Central America  Americas  ...
#
#   AID Contribution Dis Mag Value Dis Mag Scale Latitude Longitude Start Year  \
# 0              NaN           NaN           Km2      NaN       NaN       1900
# 1              NaN           NaN           Km2      NaN       NaN       1900
# 2              NaN           8.0       Richter       14       -91       1902
# 3              NaN           NaN           NaN      NaN       NaN       1902
# 4              NaN           NaN           NaN      NaN       NaN       1902
#
#   Start Month  End Year  End Month          CPI
# 0         NaN      1900        NaN  2,849084409
# 1         NaN      1900        NaN  2,849084409
# 2         4.0      1902        4.0  2,963047785
# 3         4.0      1902        4.0  2,963047785
# 4        10.0      1902       10.0  2,963047785
#
# [5 rows x 27 columns]

# %%
df[500:520]
# Out:
#             Dis No  Year   Seq Disaster Subgroup Disaster Type  \
# 500  1969-9006-BEN  1969  9006    Climatological       Drought
# 501  1969-9006-BFA  1969  9006    Climatological       Drought
# 502  1969-9006-CPV  1969  9006    Climatological       Drought
# 503  1969-9006-GMB  1969  9006    Climatological       Drought
# 504  1969-9006-GNB  1969  9006    Climatological       Drought
# 505  1969-0004-BFA  1969     4        Biological      Epidemic
# 506  1969-0099-BFA  1969    99        Biological      Epidemic
# 507  1969-0065-BGD  1969    65    Meteorological         Storm
# 508  1969-0048-BOL  1969    48        Biological      Epidemic
# 509  1969-0108-BOL  1969   108        Biological      Epidemic
# 510  1969-0057-BRA  1969    57      Hydrological         Flood
# 511  1969-0082-CHN  1969    82       Geophysical    Earthquake
# 512  1969-0066-CHN  1969    66      Hydrological         Flood
# 513  1969-0110-COL  1969   110      Hydrological         Flood
# 514  1969-0103-CRI  1969   103      Hydrological         Flood
# 515  1969-0112-CYP  1969   112    Meteorological         Storm
# 516  1969-0096-DZA  1969    96      Hydrological         Flood
# 517  1969-0068-ECU  1969    68        Biological      Epidemic
# 518  1969-0061-ETH  1969    61       Geophysical    Earthquake
# 519  1969-9009-ETH  1969  9009    Climatological       Drought
#
#      Disaster Subtype                           Country  ISO           Region  \
# 500           Drought                             Benin  BEN   Western Africa
# 501           Drought                      Burkina Faso  BFA   Western Africa
# 502           Drought                        Cabo Verde  CPV   Western Africa
# 503           Drought                      Gambia (the)  GMB   Western Africa
# 504           Drought                     Guinea-Bissau  GNB   Western Africa
# 505     Viral disease                      Burkina Faso  BFA   Western Africa
# 506     Viral disease                      Burkina Faso  BFA   Western Africa
# 507  Tropical cyclone                        Bangladesh  BGD    Southern Asia
# 508     Viral disease  Bolivia (Plurinational State of)  BOL    South America
# 509     Viral disease  Bolivia (Plurinational State of)  BOL    South America
# 510       Flash flood                            Brazil  BRA    South America
# 511   Ground movement                             China  CHN     Eastern Asia
# 512               NaN                             China  CHN     Eastern Asia
# 513    Riverine flood                          Colombia  COL    South America
# 514               NaN                        Costa Rica  CRI  Central America
# 515               NaN                            Cyprus  CYP     Western Asia
# 516               NaN                           Algeria  DZA  Northern Africa
# 517     Viral disease                           Ecuador  ECU    South America
# 518   Ground movement                          Ethiopia  ETH   Eastern Africa
# 519           Drought                          Ethiopia  ETH   Eastern Africa
#
#     Continent  ... AID Contribution Dis Mag Value Dis Mag Scale Latitude  \
# 500    Africa  ...              NaN           NaN           Km2      NaN
# 501    Africa  ...              NaN           NaN           Km2      NaN
# 502    Africa  ...              NaN           NaN           Km2      NaN
# 503    Africa  ...              NaN           NaN           Km2      NaN
# 504    Africa  ...              NaN           NaN           Km2      NaN
# 505    Africa  ...              NaN           NaN    Vaccinated      NaN
# 506    Africa  ...              NaN           NaN    Vaccinated      NaN
# 507      Asia  ...              NaN           NaN           Kph      NaN
# 508  Americas  ...              NaN           NaN    Vaccinated      NaN
# 509  Americas  ...              NaN           NaN    Vaccinated      NaN
# 510  Americas  ...              NaN           NaN           Km2      NaN
# 511      Asia  ...              NaN           6.0       Richter   22.317
# 512      Asia  ...              NaN           NaN           Km2      NaN
# 513  Americas  ...              NaN           NaN           Km2      NaN
# 514  Americas  ...              NaN           NaN           Km2      NaN
# 515      Asia  ...              NaN           NaN           Kph      NaN
# 516    Africa  ...              NaN           NaN           Km2      NaN
# 517  Americas  ...              NaN           NaN    Vaccinated      NaN
# 518    Africa  ...              NaN           6.0       Richter     11.9
# 519    Africa  ...              NaN           NaN           Km2      NaN
#
#     Longitude Start Year Start Month  End Year  End Month          CPI
# 500       NaN       1972         1.0      1975        NaN  12,53467526
# 501       NaN       1969         4.0      1975        NaN  12,53467526
# 502       NaN       1972         NaN      1975        NaN  12,53467526
# 503       NaN       1971         1.0      1975        NaN  12,53467526
# 504       NaN       1972         NaN      1975        NaN  12,53467526
# 505       NaN       1969         1.0      1969        1.0  12,53467526
# 506       NaN       1969        10.0      1969       10.0  12,53467526
# 507       NaN       1969         4.0      1969        4.0  12,53467526
# 508       NaN       1969         2.0      1969        2.0  12,53467526
# 509       NaN       1969        11.0      1969       11.0  12,53467526
# 510       NaN       1969         3.0      1969        3.0  12,53467526
# 511     111.8       1969         7.0      1969        7.0  12,53467526
# 512       NaN       1969         4.0      1969        4.0  12,53467526
# 513       NaN       1969        12.0      1969       12.0  12,53467526
# 514       NaN       1969        10.0      1969       10.0  12,53467526
# 515       NaN       1969        12.0      1969       12.0  12,53467526
# 516       NaN       1969         9.0      1969       10.0  12,53467526
# 517       NaN       1969         5.0      1969        5.0  12,53467526
# 518     41.21       1969         3.0      1969        3.0  12,53467526
# 519       NaN       1969         9.0      1969        NaN  12,53467526
#
# [20 rows x 27 columns]

# %%
df.tail(5)
# Out:
#               Dis No  Year  Seq Disaster Subgroup Disaster Type  \
# 16631  2023-0110-ZMB  2023  110      Hydrological         Flood
# 16632  2023-0068-ZMB  2023   68        Biological      Epidemic
# 16633  2023-0095-ZWE  2023   95    Meteorological         Storm
# 16634  2023-0022-SRB  2023   22      Hydrological         Flood
# 16635  2023-0140-SSD  2023  140        Biological      Epidemic
#
#         Disaster Subtype      Country  ISO           Region Continent  ...  \
# 16631        Flash flood       Zambia  ZMB   Eastern Africa    Africa  ...
# 16632  Bacterial disease       Zambia  ZMB   Eastern Africa    Africa  ...
# 16633   Tropical cyclone     Zimbabwe  ZWE   Eastern Africa    Africa  ...
# 16634     Riverine flood       Serbia  SRB  Southern Europe    Europe  ...
# 16635  Bacterial disease  South Sudan  SSD  Northern Africa    Africa  ...
#
#       AID Contribution Dis Mag Value Dis Mag Scale Latitude Longitude  \
# 16631              NaN           NaN           Km2      NaN       NaN
# 16632              NaN           NaN    Vaccinated      NaN       NaN
# 16633              NaN           NaN           Kph      NaN       NaN
# 16634              NaN           NaN           Km2      NaN       NaN
# 16635              NaN           NaN    Vaccinated      NaN       NaN
#
#       Start Year Start Month  End Year  End Month  CPI
# 16631       2023         2.0      2023        3.0  NaN
# 16632       2023         1.0      2023        1.0  NaN
# 16633       2023         2.0      2023        3.0  NaN
# 16634       2023         1.0      2023        1.0  NaN
# 16635       2023         2.0      2023        3.0  NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## shape, info, dtypes

# %%
df.shape
# 16636 filas y 27 columnas)
# Out:
# (16636, 27)

# %%
df.info()
# dtypes: float64(4), int64(4), object(19)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16636 entries, 0 to 16635
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dis No             16636 non-null  object
#  1   Year               16636 non-null  int64
#  2   Seq                16636 non-null  int64
#  3   Disaster Subgroup  16636 non-null  object
#  4   Disaster Type      16636 non-null  object
#  5   Disaster Subtype   13313 non-null  object
#  6   Country            16636 non-null  object
#  7   ISO                16636 non-null  object
#  8   Region             16636 non-null  object
#  9   Continent          16636 non-null  object
#  10  Location           14825 non-null  object
#  11  Origin             4085 non-null   object
#  12  Associated Dis     3593 non-null   object
#  13  Associated Dis2    763 non-null    object
#  14  OFDA Response      1716 non-null   object
#  15  Appeal             2559 non-null   object
#  16  Declaration        3343 non-null   object
#  17  AID Contribution   776 non-null    float64
#  18  Dis Mag Value      5064 non-null   float64
#  19  Dis Mag Scale      15416 non-null  object
#  20  Latitude           2775 non-null   object
#  21  Longitude          2775 non-null   object
#  22  Start Year         16636 non-null  int64
#  23  Start Month        16241 non-null  float64
#  24  End Year           16636 non-null  int64
#  25  End Month          15936 non-null  float64
#  26  CPI                16530 non-null  object
# dtypes: float64(4), int64(4), object(19)
# memory usage: 3.4+ MB

# %%
df.dtypes
# Out:
# Dis No                object
# Year                   int64
# Seq                    int64
# Disaster Subgroup     object
# Disaster Type         object
# Disaster Subtype      object
# Country               object
# ISO                   object
# Region                object
# Continent             object
# Location              object
# Origin                object
# Associated Dis        object
# Associated Dis2       object
# OFDA Response         object
# Appeal                object
# Declaration           object
# AID Contribution     float64
# Dis Mag Value        float64
# Dis Mag Scale         object
# Latitude              object
# Longitude             object
# Start Year             int64
# Start Month          float64
# End Year               int64
# End Month            float64
# CPI                   object
# dtype: object

# %% [markdown]
# ## Columnas

# %%
df.columns
# Out:
# Index(['Dis No', 'Year', 'Seq', 'Disaster Subgroup', 'Disaster Type',
#        'Disaster Subtype', 'Country', 'ISO', 'Region', 'Continent', 'Location',
#        'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response',
#        'Appeal', 'Declaration', 'AID Contribution', 'Dis Mag Value',
#        'Dis Mag Scale', 'Latitude', 'Longitude', 'Start Year', 'Start Month',
#        'End Year', 'End Month', 'CPI'],
#       dtype='object')

# %% [markdown]
# ### Columnas con valores numéricos: 8
# 'Year', 'Seq', 'AID Contribution', 'Dis Mag Value', 'Start Year', 'Start Month', 'End Year', 'End Month'

# %%
# Columnas numéricas
df.select_dtypes(include=np.number).columns.to_list() # columns.to_list muestra solo los títulos de las cols
# Out:
# ['Year',
#  'Seq',
#  'AID Contribution',
#  'Dis Mag Value',
#  'Start Year',
#  'Start Month',
#  'End Year',
#  'End Month']

# %% [markdown]
# ### Columnas con variables categóricas: 19
# 'Dis No', 'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype', 'Country', 'ISO', 'Region', 'Continent', 'Location', 'Origin', 'Associated Dis', 'Associated Dis2', 'OFDA Response', 'Appeal', 'Declaration', 'Dis Mag Scale', 'Latitude', 'Longitude', 'CPI'

# %%
# Columnas categóricas
df.select_dtypes(include=np.object).columns.to_list() # columns.to_list muestra solo los títulos de las cols
# Out:
# C:\Users\AleEng\AppData\Local\Temp\ipykernel_468\3015770914.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df.select_dtypes(include=np.object).columns.to_list() # columns.to_list muestra solo los títulos de las cols
# ['Dis No',
#  'Disaster Subgroup',
#  'Disaster Type',
#  'Disaster Subtype',
#  'Country',
#  'ISO',
#  'Region',
#  'Continent',
#  'Location',
#  'Origin',
#  'Associated Dis',
#  'Associated Dis2',
#  'OFDA Response',
#  'Appeal',
#  'Declaration',
#  'Dis Mag Scale',
#  'Latitude',
#  'Longitude',
#  'CPI']

# %% [markdown]
# .describe

# %%
df.describe(include=np.number)
# Out:
#                Year           Seq  AID Contribution  Dis Mag Value  \
# count  16636.000000  16636.000000      7.760000e+02   5.064000e+03
# mean    1997.838363    724.950228      2.003959e+04   4.667590e+04
# std       20.353457   1940.995621      1.690305e+05   3.071138e+05
# min     1900.000000      1.000000      1.000000e+00  -5.700000e+01
# 25%     1990.000000     95.000000      1.747500e+02   7.000000e+00
# 50%     2002.000000    274.000000      7.245000e+02   1.500000e+02
# 75%     2012.000000    495.000000      3.669750e+03   1.040400e+04
# max     2023.000000   9881.000000      3.518530e+06   1.302587e+07
#
#          Start Year   Start Month      End Year     End Month
# count  16636.000000  16241.000000  16636.000000  15936.000000
# mean    1997.847259      6.438766   1997.901779      6.577874
# std       20.352028      3.401005     20.340092      3.367216
# min     1900.000000      1.000000   1900.000000      1.000000
# 25%     1990.000000      4.000000   1990.000000      4.000000
# 50%     2002.000000      7.000000   2002.000000      7.000000
# 75%     2012.000000      9.000000   2012.000000      9.000000
# max     2023.000000     12.000000   2023.000000     12.000000

# %%
df.describe(include='object')
# Out:
#                Dis No Disaster Subgroup Disaster Type Disaster Subtype  \
# count           16636             16636         16636            13313
# unique          16636                 6            15               28
# top     1900-9002-CPV      Hydrological         Flood   Riverine flood
# freq                1              6612          5808             2657
#
#                                Country    ISO         Region Continent  \
# count                            16636  16636          16636     16636
# unique                             228    228             23         5
# top     United States of America (the)    USA  Southern Asia      Asia
# freq                              1131   1131           2118      6660
#
#        Location       Origin                 Associated Dis  \
# count     14825         4085                           3593
# unique    13248          710                             31
# top       North  Heavy rains  Slide (land, mud, snow, rock)
# freq         46         1709                           1324
#
#                       Associated Dis2 OFDA Response Appeal Declaration  \
# count                             763          1716   2559        3343
# unique                             31             1      2           2
# top     Slide (land, mud, snow, rock)           Yes     No          No
# freq                              289          1716   2342        2315
#
#        Dis Mag Scale Latitude Longitude          CPI
# count          15416     2775      2775        16530
# unique             5     2414      2473          114
# top              Km2    3.295    95.982  61,46318826
# freq            7067       12        12          532

# %% [markdown]
# ### Categorización de variables numéricas y categóricas por niveles según clasificación de dataset

# %%
num_lvl1 = ['Year', 'Seq']
categ_lvl1_id = ['Dis No']
categ_lvl1 = ['Disaster Subgroup', 'Disaster Type','Disaster Subtype']
categ_lvl2_geo = ['Country', 'ISO', 'Region', 'Continent', 'Location'] # 'River Basin'
categ_lvl2_geoloc = ['Latitude', 'Longitude'] # Estas pertenecen a la anterior pero es mejor separarlas debido a su carácter más específico
num_lvl2_temp = ['Start Year','Start Month', 'End Year', 'End Month'] # Son objects, evaluar si es necesario convertir a datetimes numéricas
# De num_lvl2_temp eliminar: 'Local Time', 'Start Day', 'End Day'
# categ_lvl2_time = ['Local Time']
categ_lvl2_fis = ['Origin', 'Associated Dis','Associated Dis2', 'Dis Mag Scale']
categ_lvl2_status = ['AID Contribution', 'OFDA Response', 'Appeal','Declaration'] # Coincidir con World Risk Index
# categ_lvl3_orgs = [] Se borraron los Adm Level y Admin Codes
# num_lvl3_human_impact = ['Total Deaths', 'No Injured', 'No Affected', 'No Homeless', 'Total Affected']
# num_lvl3_economic_impact = ['Reconstruction Costs', 'Reconstruction Costs Adj', 'Insured Damages', 'Insured Damages Adj', 'Total Damages', 'Total Damages Adj']

# %% [markdown]
# ## Outliers de Year

# %%
df['Year'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Gran cantidad de outliers antes de 1960

# %%
df['Year'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Tendencia a la alza en recopilación de datos de desastres a partir de 1980, siendo el pico más alto en la década del 2000

# %% [markdown]
# ## Valores faltantes

# %%
df.isnull().sum()
# Out:
# Dis No                   0
# Year                     0
# Seq                      0
# Disaster Subgroup        0
# Disaster Type            0
# Disaster Subtype      3323
# Country                  0
# ISO                      0
# Region                   0
# Continent                0
# Location              1811
# Origin               12551
# Associated Dis       13043
# Associated Dis2      15873
# OFDA Response        14920
# Appeal               14077
# Declaration          13293
# AID Contribution     15860
# Dis Mag Value        11572
# Dis Mag Scale         1220
# Latitude             13861
# Longitude            13861
# Start Year               0
# Start Month            395
# End Year                 0
# End Month              700
# CPI                    106
# dtype: int64

# %%
df.isnull()
# Out:
#        Dis No   Year    Seq  Disaster Subgroup  Disaster Type  \
# 0       False  False  False              False          False
# 1       False  False  False              False          False
# 2       False  False  False              False          False
# 3       False  False  False              False          False
# 4       False  False  False              False          False
# ...       ...    ...    ...                ...            ...
# 16631   False  False  False              False          False
# 16632   False  False  False              False          False
# 16633   False  False  False              False          False
# 16634   False  False  False              False          False
# 16635   False  False  False              False          False
#
#        Disaster Subtype  Country    ISO  Region  Continent  ...  \
# 0                 False    False  False   False      False  ...
# 1                 False    False  False   False      False  ...
# 2                 False    False  False   False      False  ...
# 3                 False    False  False   False      False  ...
# 4                 False    False  False   False      False  ...
# ...                 ...      ...    ...     ...        ...  ...
# 16631             False    False  False   False      False  ...
# 16632             False    False  False   False      False  ...
# 16633             False    False  False   False      False  ...
# 16634             False    False  False   False      False  ...
# 16635             False    False  False   False      False  ...
#
#        AID Contribution  Dis Mag Value  Dis Mag Scale  Latitude  Longitude  \
# 0                  True           True          False      True       True
# 1                  True           True          False      True       True
# 2                  True          False          False     False      False
# 3                  True           True           True      True       True
# 4                  True           True           True      True       True
# ...                 ...            ...            ...       ...        ...
# 16631              True           True          False      True       True
# 16632              True           True          False      True       True
# 16633              True           True          False      True       True
# 16634              True           True          False      True       True
# 16635              True           True          False      True       True
#
#        Start Year  Start Month  End Year  End Month    CPI
# 0           False         True     False       True  False
# 1           False         True     False       True  False
# 2           False        False     False      False  False
# 3           False        False     False      False  False
# 4           False        False     False      False  False
# ...           ...          ...       ...        ...    ...
# 16631       False        False     False      False   True
# 16632       False        False     False      False   True
# 16633       False        False     False      False   True
# 16634       False        False     False      False   True
# 16635       False        False     False      False   True
#
# [16636 rows x 27 columns]

# %% [markdown]
# ### Columnas (numéricas y categóricas) con más valores faltantes

# %% [markdown]
# Numéricas con más nulls:
# AID Contribution            15860
# Dis Mag Value               11572
# No Injured                  12489
# No Homeless                 14166
# Reconstruction Costs        16598
# Reconstruction Costs Adj    16600
# Insured Damages             15527
# Insured Damages Adj         15527
# Total Damages               11252
# Total Damages Adj           11270

# %% [markdown]
# Categóricas con más nulls:
# Origin                      12551
# Associated Dis              13043
# Associated Dis2             15873
# OFDA Response               14920
# Appeal                      14077
# Declaration                 13293
# Latitude                    13861
# Longitude                   13861
# Local Time                  15480
# River Basin                 15300

# %% [markdown]
# # Visualizaciones

# %% [markdown]
# ## Exploración de outliers en columnas numéricas (arriba de 10000 faltantes)

# %%
num_cols_outliers = ['AID Contribution', 'Dis Mag Value'] # Se sacaron 'No Injured', 'No Homeless', 'Reconstruction Costs', 'Reconstruction Costs Adj', 'Insured Damages', 'Insured Damages Adj', 'Total Damages','Total Damages Adj'
for col in num_cols_outliers:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %% [markdown]
# ## Frecuencia y distribución de variables categóricas
#
# Explorar y analizar la distribución de variables categóricas examinando sus conteos de frecuencia o proporciones.

# %% [markdown]
# Objetivo: identificar categorías que están significativamente sobrerrepresentadas o subrepresentadas en el conjunto de datos.

# %% [markdown]
# #### Definir seaborn palette Spectral

# %%
# Set Spectral palette
sns.set_palette('Spectral')
sns.set(font_scale=0.6)
palette_color = sns.color_palette('Spectral')

# %% [markdown]
# ### Nivel 1 Evento de desastre

# %% [markdown]
# #### Value counts y unique values

# %%
df['Disaster Subgroup'].value_counts()
# Out:
# Hydrological         6612
# Meteorological       5235
# Geophysical          1912
# Biological           1614
# Climatological       1262
# Extra-terrestrial       1
# Name: Disaster Subgroup, dtype: int64

# %%
df['Disaster Subgroup'].unique()
# Out:
# array(['Climatological', 'Geophysical', 'Meteorological', 'Hydrological',
#        'Biological', 'Extra-terrestrial'], dtype=object)

# %%
df['Disaster Type'].value_counts()
# Out:
# Flood                    5808
# Storm                    4618
# Earthquake               1597
# Epidemic                 1518
# Landslide                 804
# Drought                   803
# Extreme temperature       616
# Wildfire                  456
# Volcanic activity         270
# Insect infestation         95
# Mass movement (dry)        45
# Glacial lake outburst       3
# Fog                         1
# Impact                      1
# Animal accident             1
# Name: Disaster Type, dtype: int64

# %%
df['Disaster Type'].unique()
# Out:
# array(['Drought', 'Earthquake', 'Volcanic activity',
#        'Mass movement (dry)', 'Storm', 'Flood', 'Epidemic', 'Landslide',
#        'Wildfire', 'Extreme temperature', 'Fog', 'Insect infestation',
#        'Impact', 'Animal accident', 'Glacial lake outburst'], dtype=object)

# %%
df['Disaster Subtype'].value_counts()
# Out:
# Riverine flood                      2657
# Tropical cyclone                    2475
# Ground movement                     1540
# Convective storm                    1180
# Flash flood                          822
# Drought                              802
# Bacterial disease                    781
# Landslide                            587
# Viral disease                        544
# Forest fire                          314
# Cold wave                            310
# Ash fall                             248
# Heat wave                            229
# Extra-tropical storm                 148
# Avalanche                            122
# Land fire (Brush, Bush, Pasture)      92
# Coastal flood                         85
# Mudslide                              79
# Severe winter conditions              77
# Locust                                67
# Tsunami                               57
# Parasitic disease                     51
# Grasshopper                           16
# Rockfall                              12
# Lava flow                              9
# Pyroclastic flow                       4
# Worms                                  3
# Subsidence                             2
# Name: Disaster Subtype, dtype: int64

# %%
df['Disaster Subtype'].unique()
# Out:
# array(['Drought', 'Ground movement', 'Ash fall', 'Rockfall',
#        'Tropical cyclone', nan, 'Bacterial disease', 'Landslide',
#        'Avalanche', 'Forest fire', 'Riverine flood', 'Convective storm',
#        'Viral disease', 'Mudslide', 'Tsunami', 'Heat wave',
#        'Land fire (Brush, Bush, Pasture)', 'Coastal flood', 'Cold wave',
#        'Flash flood', 'Parasitic disease', 'Locust', 'Worms',
#        'Severe winter conditions', 'Grasshopper', 'Subsidence',
#        'Extra-tropical storm', 'Lava flow', 'Pyroclastic flow'],
#       dtype=object)

# %% [markdown]
# ### Visualizaciones Nivel 1 eventos de desastres

# %%
for col in categ_lvl1:
    sns.countplot(x=col, data=df)
    plt.title(f'Countplot de {col}')
    plt.xticks(rotation=75)
    plt.show()

# %% [markdown]
# ### Nivel 2 País(es)

# %% [markdown]
# ### Variables geográficas:
# Distribución geográfica: Regiones, Continentes, Localidades

# %% [markdown]
# #### Value counts y uniques geográficos

# %%
df['Country'].value_counts()
# Out:
# United States of America (the)    1131
# China                              994
# India                              760
# Philippines (the)                  684
# Indonesia                          610
#                                   ...
# Qatar                                1
# Saint BarthÃ¯Â¿Â½lemy                1
# Saint Martin (French Part)           1
# Sint Maarten (Dutch part)            1
# Isle of Man                          1
# Name: Country, Length: 228, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['Cabo Verde', 'India', 'Guatemala', 'Canada', 'Comoros (the)',
#        'Bangladesh', 'Chile', 'Colombia', 'Belgium', 'Hong Kong', 'China',
#        'France', 'Haiti', 'Indonesia', 'Burkina Faso', 'Costa Rica',
#        'Algeria', 'Gambia (the)', 'Guinea-Bissau', 'Anguilla',
#        'Germany Fed Rep', 'Ecuador', 'Bahamas (the)', 'Cuba', 'Egypt',
#        'Bulgaria', 'Guadeloupe', 'Greece', 'Dominica',
#        'Dominican Republic (the)', 'Belize', 'Fiji', 'Honduras', 'Ghana',
#        'Australia', 'Cook Islands (the)', 'Argentina', 'Azores Islands',
#        'Bermuda', 'Brazil', 'Antigua and Barbuda', 'Switzerland',
#        'Austria',
#        'United Kingdom of Great Britain and Northern Ireland (the)',
#        'Cyprus', 'Spain', 'Afghanistan', 'Netherlands Antilles',
#        'Barbados', 'Ethiopia', 'Albania', 'Guam', 'Grenada',
#        'Bolivia (Plurinational State of)', 'Botswana', 'American Samoa',
#        'Congo (the)', 'Benin', 'CÃ¯Â¿Â½te dÃ¯Â¿Â½Ivoire', 'Hungary',
#        'Cameroon', 'Guyana', 'Central African Republic', 'Czechoslovakia',
#        'Denmark', 'Djibouti', 'Burundi', 'Bahrain',
#        'United States of America (the)', 'Jamaica', 'Japan', 'Uganda',
#        'Myanmar', 'Martinique', 'Soviet Union', 'Niger (the)', 'Turkey',
#        'Italy', 'Philippines (the)', 'Taiwan (Province of China)',
#        'Romania', 'Iran (Islamic Republic of)', 'Morocco', 'Mali',
#        'Mauritania', 'Senegal', 'Chad', 'Peru', 'Tokelau', 'Puerto Rico',
#        'New Zealand', 'Pakistan', 'Jordan', 'Saint Kitts and Nevis',
#        'Montserrat', 'Poland', 'Mexico', 'Nicaragua', 'Solomon Islands',
#        'Trinidad and Tobago', 'El Salvador', 'Korea (the Republic of)',
#        'Norway', 'Papua New Guinea', 'New Caledonia', 'Sudan (the)',
#        'Libya', 'Tonga', 'RÃ¯Â¿Â½union', 'Netherlands (the)', 'Iraq',
#        'Nepal', 'Lebanon', 'Mozambique', 'Sri Lanka', 'Mongolia',
#        'Canary Is', 'Tunisia', 'French Polynesia', 'Niue', 'Saint Lucia',
#        'Mauritius', 'Somalia', 'Thailand', 'Paraguay', 'Kenya', 'Panama',
#        'Saudi Arabia', 'Tanzania, United Republic of', 'Malaysia',
#        "Lao People's Democratic Republic (the)", 'Togo', 'Malawi',
#        'Portugal', 'Syrian Arab Republic', 'Uruguay', 'Lesotho',
#        'Madagascar', 'Nigeria', 'Suriname', 'Israel', 'Kiribati',
#        'Tuvalu', 'Iceland', 'Rwanda', 'Sierra Leone', 'Sweden', 'Oman',
#        'Maldives', 'Saint Vincent and the Grenadines', 'Vanuatu',
#        'Yemen Arab Rep', 'Venezuela (Bolivarian Republic of)',
#        'South Africa', 'Viet Nam', 'Yugoslavia', 'Samoa',
#        'Wallis and Futuna', 'Congo (the Democratic Republic of the)',
#        'Yemen P Dem Rep', 'Zimbabwe', 'Zambia', 'Guinea', 'Angola',
#        'Germany Dem Rep', 'Bhutan', 'Micronesia (Federated States of)',
#        'Gabon', 'Liberia', 'Namibia', 'Ireland', 'Luxembourg',
#        'Palestine, State of', 'Cambodia',
#        "Korea (the Democratic People's Republic of)", 'Eswatini',
#        'Sao Tome and Principe', 'Turks and Caicos Islands (the)',
#        'Germany', 'Belarus', 'Finland', 'Georgia',
#        'Marshall Islands (the)', 'Kyrgyzstan', 'Lithuania',
#        'Russian Federation (the)', 'Eritrea',
#        'Macedonia (the former Yugoslav Republic of)', 'Kazakhstan',
#        'Macao', 'Virgin Island (U.S.)', 'Yemen', 'Uzbekistan',
#        'Serbia Montenegro', 'Tajikistan', 'Ukraine', 'Turkmenistan',
#        'Azerbaijan', 'Armenia', 'Brunei Darussalam',
#        'Moldova (the Republic of)', 'Czech Republic (the)',
#        'French Guiana', 'Croatia', 'Kuwait', 'Virgin Island (British)',
#        'Slovakia', 'Seychelles', 'Slovenia', 'Bosnia and Herzegovina',
#        'Latvia', 'Singapore', 'Cayman Islands (the)',
#        'Saint Helena, Ascension and Tristan da Cunha', 'Timor-Leste',
#        'Northern Mariana Islands (the)', 'Equatorial Guinea', 'Estonia',
#        'Montenegro', 'Serbia', 'South Sudan', 'Palau',
#        'United Arab Emirates (the)', 'Qatar', 'Saint BarthÃ¯Â¿Â½lemy',
#        'Saint Martin (French Part)', 'Sint Maarten (Dutch part)',
#        'Isle of Man'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Southern Asia                2118
# South-Eastern Asia           2034
# Eastern Asia                 1840
# South America                1371
# Northern America             1286
# Eastern Africa               1221
# Central America               845
# Western Africa                829
# Southern Europe               669
# Caribbean                     642
# Eastern Europe                556
# Western Europe                545
# Western Asia                  524
# Middle Africa                 452
# Northern Africa               356
# Australia and New Zealand     298
# Melanesia                     261
# Southern Africa               221
# Northern Europe               220
# Central Asia                  144
# Polynesia                      95
# Russian Federation             64
# Micronesia                     45
# Name: Region, dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['Western Africa', 'Southern Asia', 'Central America',
#        'Northern America', 'Eastern Africa', 'South America',
#        'Western Europe', 'Eastern Asia', 'Caribbean',
#        'South-Eastern Asia', 'Northern Africa', 'Eastern Europe',
#        'Southern Europe', 'Melanesia', 'Australia and New Zealand',
#        'Polynesia', 'Northern Europe', 'Western Asia', 'Micronesia',
#        'Southern Africa', 'Middle Africa', 'Russian Federation',
#        'Central Asia'], dtype=object)

# %%
df['Continent'].value_counts()
# Out:
# Asia        6660
# Americas    4144
# Africa      3079
# Europe      2054
# Oceania      699
# Name: Continent, dtype: int64

# %%
df['Continent'].unique()
# Out:
# array(['Africa', 'Asia', 'Americas', 'Europe', 'Oceania'], dtype=object)

# %%
df['Location'].value_counts()
# Out:
# North                                                                                                                                    46
# South                                                                                                                                    38
# Countrywide                                                                                                                              34
# Central                                                                                                                                  30
# Taiwan Sheng province                                                                                                                    23
#                                                                                                                                          ..
# Kakheti, Kvemo Kartli, Samtskhe-Javakheti, Mtskheta-Mtianeti, Shida Kartli, Imereti provinces                                             1
# Mamou, LabÃ¯Â¿Â½, TouguÃ¯Â¿Â½, Mali, Koubia, Kankan, Kindia districts. 15 districts in northwestern.                                      1
# Upper River division                                                                                                                      1
# Michalitsi, Mitikas (Artis District, Ipeiros province), Flampoura, Kanali, Pantokratos villages (Prevezis district, Ipeiros province)     1
# Malakal (Upper Nile state)                                                                                                                1
# Name: Location, Length: 13248, dtype: int64

# %%
df['Location'].unique()
# Out:
# array(['Countrywide', 'Bengal', 'Quezaltenango, San Marcos', ...,
#        'Chikoma, Mbande, Mzigawa, Chipanji, Mlawe, Eastern, Luapula, Lusaka, Southern',
#        'Sjenica and Brodarevo Novi Pazar Municipality; Novi Pazar Municipality (Sumadija and Western Serbia Region, south-western Serbia)',
#        'Malakal (Upper Nile state)'], dtype=object)

# %% [markdown]
# ### Visualizaciones Nivel 2: variables geográficas

# %% [markdown]
# #### Countplots

# %%
geo_cols = ['Region', 'Continent']
# Realizar countplot solo con Region y Continent,
# No Country ni Location: demasiados resultados

for col in geo_cols:
    sns.countplot(x=col, data=df)
    plt.title(f'Countplot de {col}')
    plt.xticks(rotation=75)
    plt.show()

# %% [markdown]
# #### Pie Charts

# %%
geo_cols = ['Continent']

for col in geo_cols:
    category_counts = df[col].value_counts()
    labels = category_counts.index
    sizes = category_counts.values

    plt.pie(x=sizes, labels=labels, colors=palette_color, autopct='%.0f%%')
    plt.title(f'Gráfica de Pie de {col}')
    plt.legend(fontsize=6)
    plt.show()

# %% [markdown]
# ### Variables características físicas:
# Distribución de: Origen, Desastres Asociados 1 y 2, Escala de Magnitud de Desastre

# %%
# Pivot table
# Visualización relacional

# %% [markdown]
# ### Visualizaciones Nivel 2: características físicas
